# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
start ='2017-05-14'
end  ='2019-05-12'
df=data.get_data_tiingo('TSLA',start,end,api_key='e064da3d7204d772e0365bc82d9881329c0bdf46')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas_datareader\tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   return pd.concat(dfs, self._concat_axis)

# %%
df.tail()
# Out:
#                                    close    high     low    open    volume  \
# symbol date
# TSLA   2019-05-06 00:00:00+00:00  255.34  258.35  248.50  250.02  10833900
#        2019-05-07 00:00:00+00:00  247.06  257.21  245.10  256.80  10131400
#        2019-05-08 00:00:00+00:00  244.84  250.60  244.20  246.94   6176400
#        2019-05-09 00:00:00+00:00  241.98  243.68  236.94  242.00   6711400
#        2019-05-10 00:00:00+00:00  239.52  241.99  236.02  239.75   7008300
#
#                                   adjClose  adjHigh  adjLow  adjOpen  \
# symbol date
# TSLA   2019-05-06 00:00:00+00:00    51.068   51.670  49.700   50.004
#        2019-05-07 00:00:00+00:00    49.412   51.442  49.020   51.360
#        2019-05-08 00:00:00+00:00    48.968   50.120  48.840   49.388
#        2019-05-09 00:00:00+00:00    48.396   48.736  47.388   48.400
#        2019-05-10 00:00:00+00:00    47.904   48.398  47.204   47.950
#
#                                   adjVolume  divCash  splitFactor
# symbol date
# TSLA   2019-05-06 00:00:00+00:00   54169500      0.0          1.0
#        2019-05-07 00:00:00+00:00   50657000      0.0          1.0
#        2019-05-08 00:00:00+00:00   30882000      0.0          1.0
#        2019-05-09 00:00:00+00:00   33557000      0.0          1.0
#        2019-05-10 00:00:00+00:00   35041500      0.0          1.0

# %%
df.shape
# Out:
# (501, 12)

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#   symbol                      date   close    high     low    open   volume  \
# 0   TSLA 2017-05-15 00:00:00+00:00  315.88  320.20  312.53  318.38  7568594
# 1   TSLA 2017-05-16 00:00:00+00:00  317.01  320.06  315.14  317.59  4121619
# 2   TSLA 2017-05-17 00:00:00+00:00  306.11  314.63  305.50  314.39  6675795
# 3   TSLA 2017-05-18 00:00:00+00:00  313.06  313.94  305.31  307.00  5590416
# 4   TSLA 2017-05-19 00:00:00+00:00  310.83  316.50  310.20  315.50  4639506
#
#    adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  splitFactor
# 0    63.176   64.040  62.506   63.676   37842970      0.0          1.0
# 1    63.402   64.012  63.028   63.518   20608095      0.0          1.0
# 2    61.222   62.926  61.100   62.878   33378975      0.0          1.0
# 3    62.612   62.788  61.062   61.400   27952080      0.0          1.0
# 4    62.166   63.300  62.040   63.100   23197530      0.0          1.0

# %%
df=df.drop(['date','adjClose'],axis=1)
df.head()
# Out:
#   symbol   close    high     low    open   volume  adjHigh  adjLow  adjOpen  \
# 0   TSLA  315.88  320.20  312.53  318.38  7568594   64.040  62.506   63.676
# 1   TSLA  317.01  320.06  315.14  317.59  4121619   64.012  63.028   63.518
# 2   TSLA  306.11  314.63  305.50  314.39  6675795   62.926  61.100   62.878
# 3   TSLA  313.06  313.94  305.31  307.00  5590416   62.788  61.062   61.400
# 4   TSLA  310.83  316.50  310.20  315.50  4639506   63.300  62.040   63.100
#
#    adjVolume  divCash  splitFactor
# 0   37842970      0.0          1.0
# 1   20608095      0.0          1.0
# 2   33378975      0.0          1.0
# 3   27952080      0.0          1.0
# 4   23197530      0.0          1.0

# %%
plt.plot(df.close)

# %%
df
# Out:
#     symbol   close    high     low    open    volume  adjHigh  adjLow  \
# 0     TSLA  315.88  320.20  312.53  318.38   7568594   64.040  62.506
# 1     TSLA  317.01  320.06  315.14  317.59   4121619   64.012  63.028
# 2     TSLA  306.11  314.63  305.50  314.39   6675795   62.926  61.100
# 3     TSLA  313.06  313.94  305.31  307.00   5590416   62.788  61.062
# 4     TSLA  310.83  316.50  310.20  315.50   4639506   63.300  62.040
# ..     ...     ...     ...     ...     ...       ...      ...     ...
# 496   TSLA  255.34  258.35  248.50  250.02  10833900   51.670  49.700
# 497   TSLA  247.06  257.21  245.10  256.80  10131400   51.442  49.020
# 498   TSLA  244.84  250.60  244.20  246.94   6176400   50.120  48.840
# 499   TSLA  241.98  243.68  236.94  242.00   6711400   48.736  47.388
# 500   TSLA  239.52  241.99  236.02  239.75   7008300   48.398  47.204
#
#      adjOpen  adjVolume  divCash  splitFactor
# 0     63.676   37842970      0.0          1.0
# 1     63.518   20608095      0.0          1.0
# 2     62.878   33378975      0.0          1.0
# 3     61.400   27952080      0.0          1.0
# 4     63.100   23197530      0.0          1.0
# ..       ...        ...      ...          ...
# 496   50.004   54169500      0.0          1.0
# 497   51.360   50657000      0.0          1.0
# 498   49.388   30882000      0.0          1.0
# 499   48.400   33557000      0.0          1.0
# 500   47.950   35041500      0.0          1.0
#
# [501 rows x 12 columns]

# %%
ma100=df.close.rolling(100).mean()

# %%
ma100
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 496    296.9008
# 497    295.7038
# 498    294.4862
# 499    293.1381
# 500    291.8762
# Name: close, Length: 501, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.close)
plt.plot(ma100,'r')

# %%
###Splitting Data into Training and test

# %%
data_training=pd.DataFrame(df['close'][0:int(len(df)*0.70)])
data_testing=pd.DataFrame(df['close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (350, 1)
# (151, 1)

# %%
data_training.head()
# Out:
#     close
# 0  315.88
# 1  317.01
# 2  306.11
# 3  313.06
# 4  310.83

# %%
data_testing.head()
# Out:
#       close
# 350  294.80
# 351  281.83
# 352  261.95
# 353  250.56
# 354  262.80

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))

# %%
data_training_array=scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.47841835],
#        [0.48694537],
#        [0.40469363],
#        [0.45713855],
#        [0.4403109 ],
#        [0.4366888 ],
#        [0.38771506],
#        [0.43570782],
#        [0.48558708],
#        [0.5482946 ],
#        [0.62345306],
#        [0.66805011],
#        [0.66322065],
#        [0.65929671],
#        [0.71566556],
#        [0.75739511],
#        [0.80870812],
#        [0.88680954],
#        [0.79112587],
#        [0.80387866],
#        [0.93170842],
#        [0.96725023],
#        [0.92710534],
#        [0.89737398],
#        [0.88530033],
#        [0.90371265],
#        [0.93510414],
#        [0.98196499],
#        [0.98830365],
#        [0.94332931],
#        [0.82923332],
#        [0.89616662],
#        [0.81700875],
#        [0.82349834],
#        [0.75565952],
#        [0.56300936],
#        [0.42521883],
#        [0.45834591],
#        [0.47970118],
#        [0.56399034],
#        [0.58134621],
#        [0.53523996],
#        [0.56821612],
#        [0.50626321],
#        [0.57168729],
#        [0.54920012],
#        [0.58436462],
#        [0.57289466],
#        [0.67944461],
#        [0.6574102 ],
#        [0.68948083],
#        [0.6186236 ],
#        [0.62322668],
#        [0.53569273],
#        [0.50626321],
#        [0.55395412],
#        [0.71392997],
#        [0.788032  ],
#        [0.7749019 ],
#        [0.85073951],
#        [0.83798672],
#        [0.77663749],
#        [0.79410655],
#        [0.84002415],
#        [0.82893148],
#        [0.83330818],
#        [0.7503773 ],
#        [0.716722  ],
#        [0.64428011],
#        [0.67061576],
#        [0.75679143],
#        [0.75799879],
#        [0.72117416],
#        [0.70313915],
#        [0.7159674 ],
#        [0.7598853 ],
#        [0.7804105 ],
#        [0.77663749],
#        [0.73279505],
#        [0.69461213],
#        [0.740492  ],
#        [0.68608512],
#        [0.83919408],
#        [0.83210081],
#        [0.858361  ],
#        [0.94446121],
#        [0.9608361 ],
#        [1.        ],
#        [0.9252943 ],
#        [0.91631452],
#        [0.86024751],
#        [0.7441141 ],
#        [0.69808331],
#        [0.70004528],
#        [0.66774826],
#        [0.6574102 ],
#        [0.66872925],
#        [0.67197404],
#        [0.72185331],
#        [0.77369454],
#        [0.77610927],
#        [0.78780561],
#        [0.68261395],
#        [0.77807123],
#        [0.77060066],
#        [0.77875038],
#        [0.77792031],
#        [0.74041654],
#        [0.7792786 ],
#        [0.80870812],
#        [0.74954724],
#        [0.69891337],
#        [0.63794144],
#        [0.64035617],
#        [0.55357682],
#        [0.55606701],
#        [0.51607305],
#        [0.51011168],
#        [0.59651373],
#        [0.51765771],
#        [0.35300332],
#        [0.40454271],
#        [0.37956535],
#        [0.40424087],
#        [0.39171446],
#        [0.38115002],
#        [0.38115002],
#        [0.47479626],
#        [0.42423785],
#        [0.44385753],
#        [0.45291277],
#        [0.47215515],
#        [0.42453969],
#        [0.49298219],
#        [0.45366737],
#        [0.47592816],
#        [0.48543616],
#        [0.49102022],
#        [0.41548446],
#        [0.42536976],
#        [0.40786296],
#        [0.39782674],
#        [0.3865077 ],
#        [0.45864775],
#        [0.44340477],
#        [0.47275883],
#        [0.57674313],
#        [0.66820103],
#        [0.65310896],
#        [0.64450649],
#        [0.68646242],
#        [0.6519016 ],
#        [0.59326894],
#        [0.57727136],
#        [0.59749472],
#        [0.54874736],
#        [0.48905826],
#        [0.44642318],
#        [0.47449442],
#        [0.44423483],
#        [0.5135074 ],
#        [0.48875641],
#        [0.46891035],
#        [0.48370057],
#        [0.63333836],
#        [0.61281316],
#        [0.62118925],
#        [0.64495925],
#        [0.63190462],
#        [0.66088138],
#        [0.71445819],
#        [0.69491398],
#        [0.73603984],
#        [0.74766073],
#        [0.75694235],
#        [0.70487474],
#        [0.64261998],
#        [0.6819348 ],
#        [0.73234229],
#        [0.70434651],
#        [0.76841232],
#        [0.7302294 ],
#        [0.68872623],
#        [0.60858738],
#        [0.61492605],
#        [0.69815877],
#        [0.47351343],
#        [0.43721702],
#        [0.47728645],
#        [0.53712647],
#        [0.52693933],
#        [0.61568065],
#        [0.62639602],
#        [0.62096287],
#        [0.60987021],
#        [0.70698762],
#        [0.75135829],
#        [0.79188047],
#        [0.74335949],
#        [0.68351947],
#        [0.59198612],
#        [0.62360398],
#        [0.61024751],
#        [0.57138545],
#        [0.60232418],
#        [0.57817688],
#        [0.56361304],
#        [0.70200724],
#        [0.67431331],
#        [0.55953818],
#        [0.55176577],
#        [0.51969514],
#        [0.46091156],
#        [0.43819801],
#        [0.48332327],
#        [0.42725626],
#        [0.37020827],
#        [0.39012979],
#        [0.20147902],
#        [0.03999396],
#        [0.10300332],
#        [0.        ],
#        [0.11356776],
#        [0.26003622],
#        [0.40175068],
#        [0.35330516],
#        [0.28056142],
#        [0.39405373],
#        [0.36560519],
#        [0.31391488],
#        [0.36115303],
#        [0.29225777],
#        [0.26569574],
#        [0.30840628],
#        [0.35919107],
#        [0.28493812],
#        [0.23309689],
#        [0.23377603],
#        [0.21287353],
#        [0.24901902],
#        [0.31391488],
#        [0.3125566 ],
#        [0.3579837 ],
#        [0.36726532],
#        [0.2412466 ],
#        [0.31399034],
#        [0.37948989],
#        [0.37345306],
#        [0.41027769],
#        [0.39646846],
#        [0.36658618],
#        [0.29799276],
#        [0.23920918],
#        [0.25656505],
#        [0.24192575],
#        [0.18367039],
#        [0.24154845],
#        [0.17001207],
#        [0.20064896],
#        [0.1914428 ],
#        [0.19898883],
#        [0.23603984],
#        [0.29610625],
#        [0.24335949],
#        [0.29686085],
#        [0.33398732],
#        [0.29165409],
#        [0.50573498],
#        [0.48000302],
#        [0.49185029],
#        [0.60081497],
#        [0.68133112],
#        [0.69649864],
#        [0.79414428],
#        [0.79753999],
#        [0.89307274],
#        [0.7551313 ],
#        [0.82810142],
#        [0.71709931],
#        [0.6123604 ],
#        [0.60768186],
#        [0.67552068],
#        [0.69438575],
#        [0.7353607 ],
#        [0.68268941],
#        [0.62322668],
#        [0.44053728],
#        [0.42770903],
#        [0.42574706],
#        [0.49826441],
#        [0.52814669],
#        [0.50166013],
#        [0.48468156],
#        [0.50098098],
#        [0.43480229],
#        [0.52980682],
#        [0.53856022],
#        [0.51124359],
#        [0.46106248],
#        [0.38273468],
#        [0.33919408],
#        [0.42453969],
#        [0.40876849],
#        [0.33730758],
#        [0.2844099 ],
#        [0.34455177],
#        [0.36492605],
#        [0.73241775],
#        [0.72207969],
#        [0.67544522],
#        [0.95902505],
#        [0.88937519],
#        [0.7543767 ],
#        [0.77731663],
#        [0.78425898],
#        [0.71808029],
#        [0.65054331],
#        [0.62609417],
#        [0.40009055],
#        [0.42227588],
#        [0.52384546],
#        [0.52188349],
#        [0.5102626 ],
#        [0.53078781],
#        [0.5039994 ],
#        [0.44808331],
#        [0.396393  ],
#        [0.38235738],
#        [0.37111379],
#        [0.27520374],
#        [0.21325083],
#        [0.2148355 ],
#        [0.08119529],
#        [0.24916994],
#        [0.20344099],
#        [0.28720193],
#        [0.27905222],
#        [0.32236644],
#        [0.31964986],
#        [0.24509508],
#        [0.35119227],
#        [0.34598551],
#        [0.35179596],
#        [0.35617265],
#        [0.36605795],
#        [0.43087836],
#        [0.41533353],
#        [0.09274072],
#        [0.43932991],
#        [0.36628433]])

# %%
x_train=[]
y_train=[]

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])

# %%
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (250, 100, 1)

# %%
## ML Model

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model=Sequential()
model.add(LSTM(units=50, activation ='relu' , return_sequences=True,
              input_shape =(x_train.shape[1],1)))
model.add(Dropout(0.2))


model.add(LSTM(units=60, activation ='relu' , return_sequences=True,))
model.add(Dropout(0.3))


model.add(LSTM(units=80, activation ='relu' , return_sequences=True,))
model.add(Dropout(0.4))


model.add(LSTM(units=120, activation ='relu'))
model.add(Dropout(0.5))


model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 100, 50)           10400
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  lstm_6 (LSTM)               (None, 100, 60)           26640
#
#  dropout_5 (Dropout)         (None, 100, 60)           0
#
#  lstm_7 (LSTM)               (None, 100, 80)           45120
#
#  dropout_6 (Dropout)         (None, 100, 80)           0
#
#  lstm_8 (LSTM)               (None, 120)               96480
#
#  dropout_7 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 1)                 121
#
# =================================================================
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 14s 618ms/step - loss: 0.2227
# Epoch 2/50
# 8/8 [==============================] - 5s 687ms/step - loss: 0.0562
# Epoch 3/50
# 8/8 [==============================] - 5s 673ms/step - loss: 0.0393
# Epoch 4/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.0389
# Epoch 5/50
# 8/8 [==============================] - 6s 672ms/step - loss: 0.0385
# Epoch 6/50
# 8/8 [==============================] - 5s 698ms/step - loss: 0.0403
# Epoch 7/50
# 8/8 [==============================] - 4s 526ms/step - loss: 0.0394
# Epoch 8/50
# 8/8 [==============================] - 4s 488ms/step - loss: 0.0402
# Epoch 9/50
# 8/8 [==============================] - 4s 451ms/step - loss: 0.0349
# Epoch 10/50
# 8/8 [==============================] - 4s 459ms/step - loss: 0.0341
# Epoch 11/50
# 8/8 [==============================] - 4s 494ms/step - loss: 0.0358
# Epoch 12/50
# 8/8 [==============================] - 4s 566ms/step - loss: 0.0342
# Epoch 13/50
# 8/8 [==============================] - 4s 434ms/step - loss: 0.0334
# Epoch 14/50
# 8/8 [==============================] - 5s 577ms/step - loss: 0.0343
# Epoch 15/50
# 8/8 [==============================] - 4s 449ms/step - loss: 0.0348
# Epoch 16/50
# 8/8 [==============================] - 4s 501ms/step - loss: 0.0296
# Epoch 17/50
# 8/8 [==============================] - 4s 455ms/step - loss: 0.0319
# Epoch 18/50
# 8/8 [==============================] - 4s 441ms/step - loss: 0.0336
# Epoch 19/50
# 8/8 [==============================] - 4s 450ms/step - loss: 0.0314
# Epoch 20/50
# 8/8 [==============================] - 4s 447ms/step - loss: 0.0318
# Epoch 21/50
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0310
# Epoch 22/50
# 8/8 [==============================] - 4s 443ms/step - loss: 0.0338
# Epoch 23/50
# 8/8 [==============================] - 4s 446ms/step - loss: 0.0319
# Epoch 24/50
# 8/8 [==============================] - 3s 430ms/step - loss: 0.0313
# Epoch 25/50
# 8/8 [==============================] - 4s 439ms/step - loss: 0.0314
# Epoch 26/50
# 8/8 [==============================] - 4s 488ms/step - loss: 0.0312
# Epoch 27/50
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0296
# Epoch 28/50
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0285
# Epoch 29/50
# 8/8 [==============================] - 3s 381ms/step - loss: 0.0285
# Epoch 30/50
# 8/8 [==============================] - 3s 387ms/step - loss: 0.0266
# Epoch 31/50
# 8/8 [==============================] - 5s 625ms/step - loss: 0.0255
# Epoch 32/50
# 8/8 [==============================] - 4s 448ms/step - loss: 0.0262
# Epoch 33/50
# 8/8 [==============================] - 4s 463ms/step - loss: 0.0274
# Epoch 34/50
# 8/8 [==============================] - 3s 437ms/step - loss: 0.0263
# Epoch 35/50
# 8/8 [==============================] - 4s 438ms/step - loss: 0.0275
# Epoch 36/50
# 8/8 [==============================] - 4s 441ms/step - loss: 0.0272
# Epoch 37/50
# 8/8 [==============================] - 4s 433ms/step - loss: 0.0273
# Epoch 38/50
# 8/8 [==============================] - 3s 432ms/step - loss: 0.0257
# Epoch 39/50
# 8/8 [==============================] - 4s 472ms/step - loss: 0.0289
# Epoch 40/50
# 8/8 [==============================] - 4s 544ms/step - loss: 0.0263
# Epoch 41/50
# 8/8 [==============================] - 4s 515ms/step - loss: 0.0236
# Epoch 42/50
# 8/8 [==============================] - 3s 399ms/step - loss: 0.0243
# Epoch 43/50
# 8/8 [==============================] - 3s 372ms/step - loss: 0.0251
# Epoch 44/50
# 8/8 [==============================] - 3s 381ms/step - loss: 0.0234
# Epoch 45/50
# 8/8 [==============================] - 3s 404ms/step - loss: 0.0259
# Epoch 46/50
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0230
# Epoch 47/50
# 8/8 [==============================] - 3s 374ms/step - loss: 0.0232
# Epoch 48/50
# 8/8 [==============================] - 3s 378ms/step - loss: 0.0238
# Epoch 49/50
# 8/8 [==============================] - 3s 416ms/step - loss: 0.0207
# Epoch 50/50
# 8/8 [==============================] - 3s 369ms/step - loss: 0.0218

# %%
model.save('keras_model.h5')

# %%
past_100_days=data_training.tail(100)

# %%
final_df=past_100_days.append(data_testing,ignore_index=True)

# %%
final_df.head()
# Out:
#     close
# 0  301.06
# 1  291.97
# 2  284.18
# 3  286.48
# 4  284.54

# %%
input_data=scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.46063479],
#        [0.39818631],
#        [0.34466887],
#        [0.36046991],
#        [0.34714207],
#        [0.29410552],
#        [0.34679857],
#        [0.28167079],
#        [0.30956307],
#        [0.30118164],
#        [0.30805166],
#        [0.34178346],
#        [0.39646881],
#        [0.34844738],
#        [0.39715581],
#        [0.43095631],
#        [0.3924155 ],
#        [0.58731794],
#        [0.56389118],
#        [0.57467711],
#        [0.67388019],
#        [0.74718329],
#        [0.76099203],
#        [0.84989008],
#        [0.85298159],
#        [0.93995603],
#        [0.81437208],
#        [0.88080517],
#        [0.77974718],
#        [0.68439132],
#        [0.6801319 ],
#        [0.74189338],
#        [0.75906843],
#        [0.79637263],
#        [0.7484199 ],
#        [0.69428414],
#        [0.52796098],
#        [0.51628195],
#        [0.51449574],
#        [0.58051663],
#        [0.6077219 ],
#        [0.58360813],
#        [0.56815059],
#        [0.58298983],
#        [0.52273976],
#        [0.60923331],
#        [0.61720253],
#        [0.59233306],
#        [0.54664743],
#        [0.47533663],
#        [0.43569662],
#        [0.51339654],
#        [0.4990382 ],
#        [0.43397912],
#        [0.38582028],
#        [0.44057433],
#        [0.45912339],
#        [0.79369332],
#        [0.7842814 ],
#        [0.74182468],
#        [1.        ],
#        [0.93658972],
#        [0.81368508],
#        [0.83456994],
#        [0.84089035],
#        [0.78064029],
#        [0.71915361],
#        [0.69689475],
#        [0.49113768],
#        [0.51133553],
#        [0.60380599],
#        [0.60201979],
#        [0.59143996],
#        [0.61012641],
#        [0.58573784],
#        [0.534831  ],
#        [0.48777137],
#        [0.47499313],
#        [0.4647568 ],
#        [0.37743886],
#        [0.321036  ],
#        [0.3224787 ],
#        [0.20081066],
#        [0.35373729],
#        [0.31210497],
#        [0.38836219],
#        [0.38094257],
#        [0.42037648],
#        [0.41790327],
#        [0.35002748],
#        [0.44661995],
#        [0.44187964],
#        [0.44716955],
#        [0.45115416],
#        [0.46015389],
#        [0.51916735],
#        [0.50501511],
#        [0.21132179],
#        [0.52686178],
#        [0.46035999],
#        [0.41762847],
#        [0.32852432],
#        [0.19194834],
#        [0.11369882],
#        [0.19778785],
#        [0.15711734],
#        [0.12517175],
#        [0.17017038],
#        [0.17573509],
#        [0.29252542],
#        [0.25948063],
#        [0.20541358],
#        [0.1785518 ],
#        [0.18507832],
#        [0.41309426],
#        [0.37434735],
#        [0.55544106],
#        [0.66563616],
#        [0.69277274],
#        [0.65876614],
#        [0.70974169],
#        [0.75755702],
#        [0.77219016],
#        [0.73777137],
#        [0.73543556],
#        [0.7842127 ],
#        [0.80647156],
#        [0.80035724],
#        [0.66824677],
#        [0.71942841],
#        [0.75563342],
#        [0.7861363 ],
#        [0.82646331],
#        [0.8206925 ],
#        [0.77960978],
#        [0.7157186 ],
#        [0.63080517],
#        [0.76937345],
#        [0.75508381],
#        [0.78222039],
#        [0.73619126],
#        [0.80015114],
#        [0.85517999],
#        [0.86349272],
#        [0.88657598],
#        [0.85160758],
#        [0.90093432],
#        [0.91199505],
#        [0.91089585],
#        [0.98090135],
#        [0.90478153],
#        [0.7859989 ],
#        [0.70774938],
#        [0.6798571 ],
#        [0.55901347],
#        [0.58917285],
#        [0.42168178],
#        [0.63259137],
#        [0.56416598],
#        [0.68604012],
#        [0.6786892 ],
#        [0.52287716],
#        [0.45582578],
#        [0.57488321],
#        [0.69352844],
#        [0.69620775],
#        [0.71805441],
#        [0.76229733],
#        [0.77802968],
#        [0.68968123],
#        [0.75858752],
#        [0.76971696],
#        [0.77837318],
#        [0.46887881],
#        [0.44593295],
#        [0.36809563],
#        [0.39502611],
#        [0.43301731],
#        [0.4284831 ],
#        [0.43590272],
#        [0.51360264],
#        [0.5015801 ],
#        [0.5372355 ],
#        [0.54190712],
#        [0.60002748],
#        [0.5716543 ],
#        [0.50494641],
#        [0.49319868],
#        [0.54156362],
#        [0.5344875 ],
#        [0.50948063],
#        [0.47925254],
#        [0.50748832],
#        [0.49209948],
#        [0.47093982],
#        [0.3931025 ],
#        [0.41701017],
#        [0.44490245],
#        [0.43865073],
#        [0.55461665],
#        [0.58992855],
#        [0.41755977],
#        [0.35277549],
#        [0.29218192],
#        [0.29012091],
#        [0.29252542],
#        [0.34439406],
#        [0.39097279],
#        [0.33903545],
#        [0.37750756],
#        [0.38437758],
#        [0.2845562 ],
#        [0.24374828],
#        [0.22987084],
#        [0.27198406],
#        [0.27486947],
#        [0.20967299],
#        [0.18143721],
#        [0.23193185],
#        [0.28043419],
#        [0.30647156],
#        [0.31499038],
#        [0.37901896],
#        [0.3563479 ],
#        [0.39708711],
#        [0.23200055],
#        [0.28132729],
#        [0.26923605],
#        [0.26312174],
#        [0.28888431],
#        [0.23639736],
#        [0.23145095],
#        [0.22238252],
#        [0.27033526],
#        [0.25570212],
#        [0.26964826],
#        [0.19744435],
#        [0.20534487],
#        [0.16934597],
#        [0.09356966],
#        [0.00776312],
#        [0.05125034],
#        [0.03215169],
#        [0.        ],
#        [0.06931849],
#        [0.1444078 ],
#        [0.14653751],
#        [0.08965375],
#        [0.07440231],
#        [0.05475405],
#        [0.03785381]])

# %%
input_data.shape
# Out:
# (251, 1)

# %%
x_test=[]
y_test=[]

for i in range(100,input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

# %%
x_test , y_test=  np.array(x_test),np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (151, 100, 1)
# (151,)

# %%
## Making Predictions

# %%
y_predicted =model.predict(x_test)
# Out:
# 5/5 [==============================] - 2s 118ms/step

# %%
y_predicted.shape
# Out:
# (151, 1)

# %%
scaler.scale_
# Out:
# array([0.00687002])

# %%
scale_factor=1/0.00687002
y_predicted=y_predicted* scale_factor
y_test = y_test* scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'b',label="Original Price")
plt.plot(y_predicted,'r',label="Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
